# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# Its recommended to create a custom exception by defining a new class that inherits from 'Exception' class because it serves as the base class for all
# exceptions,and provide a common way to handle exceptions.
#
# By using custom exception class, you can create specific exception types that can be raised and caught in a specific way, that makes our code more structured and easy to understand and maintain

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
def hierarchy(exception_class):
    print(exception_class)
    for subclass in exception_class.__subclasses__():
        hierarchy(subclass)

hierarchy(Exception)
# Out:
# <class 'Exception'>
# <class 'TypeError'>
# <class 'decimal.FloatOperation'>
# <class 'email.errors.MultipartConversionError'>
# <class 'StopAsyncIteration'>
# <class 'StopIteration'>
# <class 'ImportError'>
# <class 'ModuleNotFoundError'>
# <class 'zipimport.ZipImportError'>
# <class 'OSError'>
# <class 'ConnectionError'>
# <class 'BrokenPipeError'>
# <class 'ConnectionAbortedError'>
# <class 'ConnectionRefusedError'>
# <class 'ConnectionResetError'>
# <class 'http.client.RemoteDisconnected'>
# <class 'BlockingIOError'>
# <class 'ChildProcessError'>
# <class 'FileExistsError'>
# <class 'FileNotFoundError'>
# <class 'IsADirectoryError'>
# <class 'NotADirectoryError'>
# <class 'InterruptedError'>
# <class 'zmq.error.InterruptedSystemCall'>
# <class 'PermissionError'>
# <class 'ProcessLookupError'>
# <class 'TimeoutError'>
# <class 'io.UnsupportedOperation'>
# <class 'signal.itimer_error'>
# <class 'socket.herror'>
# <class 'socket.gaierror'>
# <class 'ssl.SSLError'>
# ...

# %%
def hierarchy(exception_class):
    print(exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        hierarchy(subclass)

hierarchy(Exception)
# Out:
# Exception
# TypeError
# FloatOperation
# MultipartConversionError
# StopAsyncIteration
# StopIteration
# ImportError
# ModuleNotFoundError
# ZipImportError
# OSError
# ConnectionError
# BrokenPipeError
# ConnectionAbortedError
# ConnectionRefusedError
# ConnectionResetError
# RemoteDisconnected
# BlockingIOError
# ChildProcessError
# FileExistsError
# FileNotFoundError
# IsADirectoryError
# NotADirectoryError
# InterruptedError
# InterruptedSystemCall
# PermissionError
# ProcessLookupError
# TimeoutError
# UnsupportedOperation
# itimer_error
# herror
# gaierror
# SSLError
# SSLCertVerificationError
# SSLZeroReturnError
# SSLWantWriteError
# SSLWantReadError
# SSLSyscallError
# SSLEOFError
# Error
# SameFileError
# SpecialFileError
# ExecError
# ReadError
# URLError
# HTTPError
# ContentTooShortError
# BadGzipFile
# EOFError
# IncompleteReadError
# RuntimeError
# RecursionError
# NotImplementedError
# ZMQVersionError
# StdinNotImplementedError
# _DeadlockError
# BrokenBarrierError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError class is a subclass of the Exception class in Python and is used to indicate errors related to arithmetic operations.
# Some of the errors are:

# %% [markdown]
# 1. ZeroDivisionError: This error is raised when you try to divide a number by zero

# %%
2/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 2/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 2. OverflowError: This error is raised when an arithmetic operation results in a number that is too large to be represented

# %%
import math
print(math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 import math
# ----> 2 print(math.exp(1000))
#
# OverflowError: math range error

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# LookupError class in python is subclass of the Exception class, and it is used to indicate an error which occur when a value for which we are looking for in not present in the data structure

# %% [markdown]
# 1. KeyError : it is raised when you access a dictionary key that doesn't exist.

# %%
# example:
dic={"a":1,"b":2}
dic["d"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 3
#       1 # example:
#       2 dic={"a":1,"b":2}
# ----> 3 dic["d"]
#
# KeyError: 'd'

# %% [markdown]
# 2. IndexError: This error is raised when you try to access a list index that is out of range.

# %%
lst=[1,2,3,4]
lst[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 lst=[1,2,3,4]
# ----> 2 lst[8]
#
# IndexError: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError is a class of exceptions in Python that is raised when an import statement fails.

# %% [markdown]
# it can occur if:
#
#     1. the module imported doesn't exist in list of directories.
#     2. the module imported depends on another module that could not be imported

# %%
#example:

import Gravity
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 #example:
# ----> 3 import Gravity
#
# ModuleNotFoundError: No module named 'Gravity'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1.  Catch exceptions as narrowly as possible: Instead of catching a broad exception like Exception, catch only the exceptions that you know how to handle.

# %% [markdown]
# 2. Avoid catching too many exceptions: It is generally best to only catch exceptions that you know how to handle. If you catch too many exceptions, you may hide programming errors or bugs that would otherwise be more easily detected.

# %% [markdown]
# 3. Use the built-in logging module for logging exceptions: The built-in logging module is a powerful tool for logging information about errors and other events in your application. Use it to log exceptions and other errors so that you can diagnose problems more easily.

# %% [markdown]
# 4. When raising an exception, provide a meaningful error message that explains the problem. This will make it easier for other developers to understand what went wrong, and it will make debugging easier in case of an error.

# %% [markdown]
# 5. Don't catch exceptions that you can't handle: If you catch an exception and don't know how to handle it, it is better to simply propagate the exception up the call stack rather than catch and ignore it.
